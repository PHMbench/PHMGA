# %% [markdown]
# # 🛠️ PHMGA Tutorial Environment Setup
#
# 欢迎使用PHMGA教程环境配置向导！本笔记本将指导您完成所有必要的环境配置。
#
# ## 📋 配置检查清单
#
# - [ ] Python 3.8+ 环境
# - [ ] 核心依赖包安装
# - [ ] LLM Provider包安装
# - [ ] API密钥配置
# - [ ] 项目路径设置
# - [ ] 环境测试

# %% [markdown]
# ## Step 1: 检查Python环境

# %%
import sys
import platform

print(f"Python版本: {sys.version}")
print(f"操作系统: {platform.system()} {platform.release()}")
print(f"架构: {platform.machine()}")

# 检查Python版本
if sys.version_info >= (3, 8):
    print("✅ Python版本满足要求 (3.8+)")
else:
    print("❌ Python版本过低，请升级到3.8或更高版本")
# Out:
# Python版本: 3.11.13 (main, Jun  5 2025, 13:12:00) [GCC 11.2.0]
# 操作系统: Linux 6.8.0-65-generic
# 架构: x86_64
# ✅ Python版本满足要求 (3.8+)

# %% [markdown]
# ## Step 2: 安装核心依赖

# %%
import subprocess
import sys

def install_package(package):
    """安装Python包"""
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        return True
    except subprocess.CalledProcessError:
        return False

# 核心依赖包
core_packages = [
    "langchain",
    "langchain-core", 
    "langgraph",
    "langchain-community",
    "numpy",
    "scipy",
    "matplotlib",
    "pandas",
    "ipywidgets",
    "pydantic"
]

print("📦 开始安装核心依赖包...")
for package in core_packages:
    print(f"安装 {package}...", end=" ")
    if install_package(package):
        print("✅")
    else:
        print("❌")
# Out:
# 📦 开始安装核心依赖包...
# 安装 langchain... Requirement already satisfied: langchain in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain) (0.3.72)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain) (0.4.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# ✅
# 安装 langchain-core... Requirement already satisfied: langchain-core in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (0.3.72)
# Requirement already satisfied: langsmith>=0.3.45 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core) (0.4.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core) (3.11.1)
# Requirement already satisfied: requests<3,>=2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: anyio in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (4.9.0)
# Requirement already satisfied: certifi in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic>=2.7.4->langchain-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic>=2.7.4->langchain-core) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core) (1.3.1)
# ✅
# 安装 langgraph... Requirement already satisfied: langgraph in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: langchain-core>=0.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langgraph) (0.3.72)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langgraph) (2.1.1)
# Requirement already satisfied: langgraph-prebuilt<0.7.0,>=0.6.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langgraph) (0.6.0)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langgraph) (0.2.0)
# Requirement already satisfied: pydantic>=2.7.4 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langgraph) (2.11.7)
# Requirement already satisfied: xxhash>=3.5.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.10.0)
# Requirement already satisfied: httpx>=0.25.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langgraph-sdk<0.3.0,>=0.2.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langgraph-sdk<0.3.0,>=0.2.0->langgraph) (3.11.1)
# Requirement already satisfied: anyio in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (4.9.0)
# Requirement already satisfied: certifi in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (0.16.0)
# Requirement already satisfied: langsmith>=0.3.45 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (0.4.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic>=2.7.4->langgraph) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core>=0.1->langgraph) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core>=0.1->langgraph) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (1.3.1)
# ✅
# 安装 langchain-community... Requirement already satisfied: langchain-community in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-community) (0.3.72)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-community) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-community) (3.12.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-community) (0.4.8)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain-community) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
# ✅
# 安装 numpy... Requirement already satisfied: numpy in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (2.2.6)
# ✅
# 安装 scipy... Requirement already satisfied: scipy in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (1.16.1)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from scipy) (2.2.6)
# ✅
# 安装 matplotlib... Requirement already satisfied: matplotlib in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# ✅
# 安装 pandas... Requirement already satisfied: pandas in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.23.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# ✅
# 安装 ipywidgets... Collecting ipywidgets
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from ipywidgets) (9.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.14.1)
# Requirement already satisfied: wcwidth in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [ipywidgets]
# Successfully installed ipywidgets-8.1.7 jupyterlab_widgets-3.0.15 widgetsnbextension-4.0.14
# ✅
# 安装 pydantic... Requirement already satisfied: pydantic in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (2.11.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic) (0.4.1)
# ✅

# %% [markdown]
# ## Step 3: 安装LLM Provider包

# %%
# LLM Provider特定包
llm_packages = [
    ("langchain-google-genai", "Google Gemini支持"),
    ("langchain-openai", "OpenAI GPT支持"),
    ("dashscope", "通义千问支持"),
    ("zhipuai", "智谱GLM支持")
]

print("🤖 开始安装LLM Provider包...")
for package, description in llm_packages:
    print(f"安装 {package} ({description})...", end=" ")
    if install_package(package):
        print("✅")
    else:
        print(f"❌ (可选包，{description}将不可用)")
# Out:
# 🤖 开始安装LLM Provider包...
# 安装 langchain-google-genai (Google Gemini支持)... Requirement already satisfied: langchain-google-genai in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (2.0.10)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-google-genai) (0.8.5)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.37 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-google-genai) (0.3.72)
# Requirement already satisfied: pydantic<3,>=2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-google-genai) (2.11.7)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.6.15)
# Requirement already satisfied: google-api-core in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.25.1)
# Requirement already satisfied: google-api-python-client in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.177.0)
# Requirement already satisfied: google-auth>=2.15.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.40.3)
# Requirement already satisfied: protobuf in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (5.29.5)
# Requirement already satisfied: tqdm in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.67.1)
# Requirement already satisfied: typing-extensions in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.14.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.32.4)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: langsmith>=0.3.45 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.4.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic<3,>=2->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic<3,>=2->langchain-google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic<3,>=2->langchain-google-genai) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2025.7.14)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.6.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.3.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.2.3)
# ✅
# 安装 langchain-openai (OpenAI GPT支持)... Requirement already satisfied: langchain-openai in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (0.3.28)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.68 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-openai) (0.3.72)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-openai) (1.97.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: langsmith>=0.3.45 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (0.4.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-openai) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.68->langchain-openai) (3.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.67.1)
# Requirement already satisfied: idna>=2.8 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.86.0->langchain-openai) (3.10)
# Requirement already satisfied: certifi in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.68->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.68->langchain-openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.68->langchain-openai) (0.4.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-openai) (0.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.5.0)
# ✅
# 安装 dashscope (通义千问支持)... Requirement already satisfied: dashscope in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (1.24.2)
# Requirement already satisfied: aiohttp in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from dashscope) (3.12.14)
# Requirement already satisfied: requests in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from dashscope) (2.32.4)
# Requirement already satisfied: websocket-client in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from dashscope) (1.8.0)
# Requirement already satisfied: cryptography in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from dashscope) (44.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp->dashscope) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp->dashscope) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp->dashscope) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp->dashscope) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp->dashscope) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp->dashscope) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiohttp->dashscope) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp->dashscope) (3.10)
# Requirement already satisfied: typing-extensions>=4.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from aiosignal>=1.4.0->aiohttp->dashscope) (4.14.1)
# Requirement already satisfied: cffi>=1.12 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from cryptography->dashscope) (1.17.1)
# Requirement already satisfied: pycparser in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from cffi>=1.12->cryptography->dashscope) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests->dashscope) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests->dashscope) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from requests->dashscope) (2025.7.14)
# ✅
# 安装 zhipuai (智谱GLM支持)... Requirement already satisfied: zhipuai in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (2.1.5.20250825)
# Requirement already satisfied: cachetools>=4.2.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from zhipuai) (5.5.2)
# Requirement already satisfied: httpx>=0.23.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from zhipuai) (0.28.1)
# Requirement already satisfied: pydantic<3.0,>=1.9.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from zhipuai) (2.11.7)
# Requirement already satisfied: pydantic-core>=2.14.6 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from zhipuai) (2.33.2)
# Requirement already satisfied: pyjwt<2.9.0,>=2.8.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from zhipuai) (2.8.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic<3.0,>=1.9.0->zhipuai) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic<3.0,>=1.9.0->zhipuai) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from pydantic<3.0,>=1.9.0->zhipuai) (0.4.1)
# Requirement already satisfied: anyio in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx>=0.23.0->zhipuai) (4.9.0)
# Requirement already satisfied: certifi in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx>=0.23.0->zhipuai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx>=0.23.0->zhipuai) (1.0.9)
# Requirement already satisfied: idna in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpx>=0.23.0->zhipuai) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.23.0->zhipuai) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /home/lq/.conda/envs/PA/lib/python3.11/site-packages (from anyio->httpx>=0.23.0->zhipuai) (1.3.1)
# ✅

# %% [markdown]
# ## Step 4: 配置API密钥
#
# ### 4.1 创建环境变量配置文件

# %%
import os
from pathlib import Path

# 创建.env文件模板
env_template = """
# PHMGA Tutorial Environment Configuration
# 请填入您的API密钥，不需要的可以保留空白

# Google Gemini API Key
# 获取地址: https://makersuite.google.com/app/apikey
GEMINI_API_KEY=

# OpenAI API Key  
# 获取地址: https://platform.openai.com/api-keys
OPENAI_API_KEY=

# 通义千问 API Key (DashScope)
# 获取地址: https://dashscope.console.aliyun.com/ or https://bailian.console.aliyun.com/
DASHSCOPE_API_KEY=

# 智谱GLM API Key
# 获取地址: https://open.bigmodel.cn/usercenter/apikeys
ZHIPUAI_API_KEY=

# 项目路径 (自动设置，通常不需要修改)
PYTHONPATH=
""".strip()

env_path = Path.cwd().parent / ".env"
if not env_path.exists():
    with open(env_path, "w", encoding="utf-8") as f:
        f.write(env_template)
    print(f"✅ 创建环境配置文件: {env_path}")
    print("📝 请编辑此文件并填入您的API密钥")
else:
    print(f"ℹ️ 环境配置文件已存在: {env_path}")
# Out:
# ℹ️ 环境配置文件已存在: /home/lq/LQcode/2_project/PHMBench/PHMGA/.env

# %% [markdown]
# ### 4.2 加载环境变量

# %%
# 尝试从.env文件加载环境变量
try:
    from dotenv import load_dotenv
    load_dotenv(env_path)
    print("✅ 成功加载环境变量")
except ImportError:
    print("📦 安装python-dotenv以自动加载.env文件")
    install_package("python-dotenv")
    from dotenv import load_dotenv
    load_dotenv(env_path)
    print("✅ 成功加载环境变量")

# 检查API密钥状态
api_keys = [
    ("GEMINI_API_KEY", "Google Gemini"),
    ("OPENAI_API_KEY", "OpenAI GPT"), 
    ("DASHSCOPE_API_KEY", "通义千问 (Tongyi/Qwen)"),
    ("ZHIPUAI_API_KEY", "智谱GLM")
]

print("\n🔑 API密钥配置状态:")
configured_providers = []
for key, name in api_keys:
    value = os.getenv(key)
    if value and value.strip():
        print(f"  ✅ {name}: 已配置")
        configured_providers.append(name)
    else:
        print(f"  ❌ {name}: 未配置")

if configured_providers:
    print(f"\n✅ 可用的Provider: {', '.join(configured_providers)}")
else:
    print("\n⚠️  未配置任何API密钥，教程将使用Mock Provider进行演示")
# Out:
# ✅ 成功加载环境变量
#
# 🔑 API密钥配置状态:
#   ✅ Google Gemini: 已配置
#   ✅ OpenAI GPT: 已配置
#   ✅ 通义千问 (Tongyi/Qwen): 已配置
#   ✅ 智谱GLM: 已配置
#
# ✅ 可用的Provider: Google Gemini, OpenAI GPT, 通义千问 (Tongyi/Qwen), 智谱GLM

# %% [markdown]
# ### 4.3 API密钥配置指南
#
# 如果您还没有API密钥，可以通过以下链接获取：
#
# | Provider | 获取链接 | 说明 |
# |----------|----------|------|
# | **Google Gemini** | [Google AI Studio](https://makersuite.google.com/app/apikey) | 免费配额，支持多模态 |
# | **OpenAI GPT** | [OpenAI Platform](https://platform.openai.com/api-keys) | 需要付费，性能优秀 |
# | **通义千问** | [阿里云DashScope](https://dashscope.console.aliyun.com/) | 中文优化，有免费额度 |
# | **智谱GLM** | [智谱AI开放平台](https://open.bigmodel.cn/usercenter/apikeys) | 中文模型，支持长文本 |
#
# **注意**: 您至少需要配置一个API密钥，或者可以使用Mock Provider进行学习。

# %% [markdown]
# ## Step 5: 设置项目路径

# %%
import sys
from pathlib import Path

# 获取项目根目录
project_root = Path.cwd().parent
src_path = project_root / "src"

print(f"项目根目录: {project_root}")
print(f"源代码目录: {src_path}")

# 添加到Python路径
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
    print("✅ 已添加项目根目录到Python路径")

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))
    print("✅ 已添加源代码目录到Python路径")

# 设置环境变量
os.environ["PYTHONPATH"] = f"{project_root}:{src_path}"
print("✅ 已设置PYTHONPATH环境变量")
# Out:
# 项目根目录: /home/lq/LQcode/2_project/PHMBench/PHMGA
# 源代码目录: /home/lq/LQcode/2_project/PHMBench/PHMGA/src
# ✅ 已添加项目根目录到Python路径
# ✅ 已添加源代码目录到Python路径
# ✅ 已设置PYTHONPATH环境变量

# %% [markdown]
# ## Step 6: 环境测试

# %%
# 测试导入
print("🧪 测试环境配置...")

try:
    # 确保Python路径正确设置
    import sys
    import os
    from pathlib import Path
    
    project_root = Path.cwd().parent
    if str(project_root) not in sys.path:
        sys.path.insert(0, str(project_root))
    
    # 设置PYTHONPATH环境变量
    os.environ["PYTHONPATH"] = str(project_root)
    
    # 测试LangChain核心组件
    from langchain_core.language_models import BaseChatModel
    from langgraph.graph import StateGraph
    print("  ✅ LangChain/LangGraph核心组件")
    
    # 测试项目模块
    from src.model.providers import get_provider_registry, create_llm_provider
    print("  ✅ 项目provider模块")
    
    # 测试Provider注册
    registry = get_provider_registry()
    providers = registry.list_providers()
    print(f"  ✅ 可用Provider: {providers}")
    
    # 测试Mock Provider
    mock_llm = create_llm_provider("mock", "mock-model")
    response = mock_llm.invoke("测试消息")
    print(f"  ✅ Mock Provider测试: '{response[:30]}...'")
    
    print("\n✅ 环境配置测试成功！所有导入都正常工作。")
    
except Exception as e:
    print(f"  ❌ 导入测试失败: {e}")
    print("  请检查环境配置和依赖安装")
    import traceback
    traceback.print_exc()

# %% [markdown]
# ## Step 7: 配置Jupyter Widgets

# %%
# 启用Jupyter Widgets扩展
try:
    import ipywidgets
    from IPython.display import display
    import jupyter
    
    # 测试widgets
    test_widget = ipywidgets.Button(description="测试按钮")
    print("✅ Jupyter Widgets可用")
    
    # 启用扩展
    subprocess.run(["jupyter", "nbextension", "enable", "--py", "widgetsnbextension"], 
                   capture_output=True)
    print("✅ 已启用Jupyter Widgets扩展")
    
except Exception as e:
    print(f"⚠️ Jupyter Widgets配置问题: {e}")
    print("教程中的交互式组件可能无法正常工作")
# Out:
# ✅ Jupyter Widgets可用
# ✅ 已启用Jupyter Widgets扩展

# %% [markdown]
# ## 🎯 配置完成检查

# %%
from IPython.display import display, HTML

# 生成配置报告
def generate_config_report():
    """生成环境配置报告"""
    
    # 检查Python版本
    python_ok = sys.version_info >= (3, 8)
    
    # 检查核心包
    core_packages_status = {}
    for pkg in ["langchain", "langgraph", "numpy", "matplotlib"]:
        try:
            __import__(pkg.replace("-", "_"))
            core_packages_status[pkg] = True
        except ImportError:
            core_packages_status[pkg] = False
    
    # 检查API密钥
    api_status = {}
    for key, name in api_keys:
        api_status[name] = bool(os.getenv(key, "").strip())
    
    # 检查项目导入
    try:
        from src.model.providers import get_provider_registry
        project_import_ok = True
    except ImportError:
        project_import_ok = False
    
    return {
        "python_ok": python_ok,
        "core_packages": core_packages_status,
        "api_keys": api_status,
        "project_import": project_import_ok
    }

report = generate_config_report()

# 显示报告
html_report = f"""
<div style="background-color: #f8f9fa; border-radius: 10px; padding: 20px; margin: 20px 0;">
    <h2 style="color: #2c3e50; margin-top: 0;">🎯 环境配置检查报告</h2>
    
    <h3>✅ 基础环境</h3>
    <ul>
        <li>Python 3.8+: {'✅ 通过' if report['python_ok'] else '❌ 需要升级'}</li>
        <li>项目导入: {'✅ 正常' if report['project_import'] else '❌ 失败'}</li>
    </ul>
    
    <h3>📦 核心依赖</h3>
    <ul>
"""

for pkg, status in report['core_packages'].items():
    html_report += f"<li>{pkg}: {'✅ 已安装' if status else '❌ 未安装'}</li>"

html_report += """
    </ul>
    
    <h3>🔑 API密钥</h3>
    <ul>
"""

for provider, status in report['api_keys'].items():
    html_report += f"<li>{provider}: {'✅ 已配置' if status else '❌ 未配置'}</li>"

configured_count = sum(report['api_keys'].values())
overall_status = (
    report['python_ok'] and 
    report['project_import'] and 
    all(report['core_packages'].values()) and
    (configured_count > 0)  # 至少一个API密钥或者可以用Mock
)

status_color = "#27ae60" if overall_status else "#e74c3c"
status_text = "🎉 环境配置完成！" if overall_status else "⚠️ 需要完善配置"

html_report += f"""
    </ul>
    
    <div style="background-color: {status_color}; color: white; padding: 15px; border-radius: 5px; margin-top: 20px;">
        <h3 style="margin: 0;">{status_text}</h3>
        {'<p>您已经准备好开始PHMGA教程了！</p>' if overall_status else '<p>请完善上述配置后再开始教程。</p>'}
    </div>
</div>
"""

display(HTML(html_report))

# %% [markdown]
# ## 🚀 下一步
#
# 环境配置完成后，您可以：

# %%
from IPython.display import display, HTML

next_steps_html = """
<div style="display: flex; gap: 20px; margin: 20px 0;">
    <div style="flex: 1; background-color: #e8f5e8; border: 2px solid #4CAF50; border-radius: 10px; padding: 20px;">
        <h3 style="color: #2e7d32; margin-top: 0;">✅ 配置成功</h3>
        <p>恭喜！您的环境配置完成。</p>
        <a href="00_START_HERE.ipynb" 
           style="background-color: #4CAF50; color: white; padding: 10px 15px; text-decoration: none; border-radius: 5px;">
           🏠 返回主页
        </a>
        <br><br>
        <a href="Part1_Foundations/01_Complete_Tutorial.ipynb" 
           style="background-color: #2196F3; color: white; padding: 10px 15px; text-decoration: none; border-radius: 5px;">
           🚀 开始Part 1
        </a>
    </div>
    
    <div style="flex: 1; background-color: #fff3cd; border: 2px solid #ffc107; border-radius: 10px; padding: 20px;">
        <h3 style="color: #856404; margin-top: 0;">⚠️ 需要帮助?</h3>
        <p>如果遇到配置问题:</p>
        <ul style="margin: 10px 0;">
            <li>检查Python版本 ≥ 3.8</li>
            <li>重新运行pip install命令</li>
            <li>验证API密钥格式</li>
            <li>重启Jupyter Kernel</li>
        </ul>
    </div>
</div>
"""

display(HTML(next_steps_html))

# %% [markdown]
# ---
#
# ## 📝 环境配置总结
#
# 本配置向导帮助您完成了：
#
# 1. ✅ **Python环境检查** - 确保版本兼容性
# 2. ✅ **依赖包安装** - LangChain, LangGraph等核心包
# 3. ✅ **LLM Provider配置** - 多种大模型支持
# 4. ✅ **API密钥设置** - 安全的环境变量配置
# 5. ✅ **项目路径配置** - 正确的导入路径
# 6. ✅ **功能测试** - 验证环境完整性
#
# 现在您已经准备好开始PHM Graph Agent的学习之旅了！🎉
